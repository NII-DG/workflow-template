# %% [markdown]
# # R言語Kernel追加テンプレート
#
# これはDMP情報に基づき、JupyterNotebook環境にR言語Kernelを追加するためのノートブックです。
# システムによってパラメタライズされるため、手動での実行は非推奨です。

# %% [markdown]
# ## dmp.jsonから追加するR言語のバージョンを取得する

# %% [markdown]
# ## condaによるR言語のKernelとパッケージ群インストールを実験記録テンプレートの実験環境構成に追記する
# インストール方法参考： https://anaconda.org/conda-forge/r-irkernel
# インストール方法； conda install -c conda-forge r-irkernel -y
# conda install -c r r=='バージョン' r-irkernel r-essentials -yではうまくいかない

# %%
conda install -c conda-forge r-irkernel -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - r-irkernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _r-mutex-1.0.1             |      anacondar_1           3 KB  conda-forge
#     binutils_impl_linux-64-2.35.1|       h27ae35d_9         3.6 MB  defaults
#     binutils_linux-64-2.35.1   |      h454624a_30          24 KB  defaults
#     bwidget-1.9.14             |       ha770c72_1         120 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     cairo-1.16.0               |    h6cf1ce9_1008         1.5 MB  conda-forge
#     certifi-2021.10.8          |   py37h89c1867_1         145 KB  conda-forge
#     cffi-1.15.0                |   py37h036bc23_0         225 KB  conda-forge
#     curl-7.78.0                |       h1ccaba5_0          94 KB  defaults
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.13.1          |    hba837de_1005         357 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gcc_impl_linux-64-9.3.0    |      h6df7d76_17        44.6 MB  defaults
#     gcc_linux-64-9.3.0         |      h1ee779e_30          25 KB  defaults
#     gettext-0.19.8.1           |    h73d1719_1008         3.6 MB  conda-forge
#     gfortran_impl_linux-64-9.3.0|      h5abd6ed_17         8.8 MB  defaults
#     gfortran_linux-64-9.3.0    |      hf47db2c_30          24 KB  defaults
#     graphite2-1.3.13           |    h58526e2_1001         102 KB  conda-forge
#     gsl-2.6                    |       he838d99_2         3.2 MB  conda-forge
#     gxx_impl_linux-64-9.3.0    |      hbdd7822_17         9.0 MB  defaults
#     gxx_linux-64-9.3.0         |      h7e70986_30          24 KB  defaults
#     harfbuzz-2.9.1             |       h83ec7ef_1         2.0 MB  conda-forge
#     icu-68.2                   |       h9c3ff4c_0        13.1 MB  conda-forge
#     jbig-2.1                   |    h7f98852_2003          43 KB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     kernel-headers_linux-64-2.6.32|      he073ed8_15         707 KB  conda-forge
#     krb5-1.19.2                |       hcc1bbae_3         1.4 MB  conda-forge
#     ld_impl_linux-64-2.35.1    |       h7274673_9         586 KB  defaults
#     lerc-3.0                   |       h9c3ff4c_0         216 KB  conda-forge
#     libblas-3.9.0              |11_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |11_linux64_openblas          11 KB  conda-forge
#     libcurl-7.78.0             |       h0b77cf5_0         338 KB  defaults
#     libdeflate-1.8             |       h7f98852_0          67 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libffi-3.4.2               |       h7f98852_5          57 KB  conda-forge
#     libgcc-devel_linux-64-9.3.0|      hb95220a_17         2.8 MB  defaults
#     libgcc-ng-11.2.0           |      h1d223b6_11         887 KB  conda-forge
#     libgfortran-ng-9.3.0       |      ha5ec8a7_17          22 KB  defaults
#     libgfortran5-9.3.0         |      ha5ec8a7_17         1.5 MB  defaults
#     libglib-2.70.2             |       h174f98d_0         3.1 MB  conda-forge
#     libgomp-11.2.0             |      h1d223b6_11         427 KB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     liblapack-3.9.0            |11_linux64_openblas          11 KB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_1         790 KB  conda-forge
#     libnsl-2.0.0               |       h7f98852_0          31 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libstdcxx-devel_linux-64-9.3.0|      hf0c5c8d_17        10.6 MB  defaults
#     libstdcxx-ng-11.2.0        |      he4da1e4_11         4.2 MB  conda-forge
#     libtiff-4.3.0              |       h6f004c6_2         614 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libwebp-base-1.2.1         |       h7f98852_0         845 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     libxml2-2.9.12             |       h72842e0_0         772 KB  conda-forge
#     libzlib-1.2.11             |    h36c2ea0_1013          59 KB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_1         179 KB  conda-forge
#     make-4.3                   |       hd18ef5c_1         507 KB  conda-forge
#     openssl-1.1.1l             |       h7f98852_0         2.1 MB  conda-forge
#     pango-1.48.10              |       hb8ff022_1         400 KB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pixman-0.40.0              |       h36c2ea0_0         627 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     python-3.7.12              |hb7a2778_100_cpython        57.3 MB  conda-forge
#     r-base-3.6.3               |       hbcea092_8        23.4 MB  conda-forge
#     r-base64enc-0.1_3          | r36hcfec24a_1004          44 KB  conda-forge
#     r-crayon-1.3.4             |    r36h6115d3f_0         757 KB  defaults
#     r-digest-0.6.18            |    r36h96ca727_0         147 KB  defaults
#     r-evaluate-0.14            |    r36h6115d3f_2          81 KB  conda-forge
#     r-htmltools-0.3.6          |    r36h29659fb_0         172 KB  defaults
#     r-irdisplay-1.0            |    r36hd8ed1ab_0          35 KB  conda-forge
#     r-irkernel-1.2             |    r36hc72bb7e_0         157 KB  conda-forge
#     r-jsonlite-1.7.2           |    r36hcfec24a_0         462 KB  conda-forge
#     r-pbdzmq-0.3_3             |    r36h5455479_1         380 KB  defaults
#     r-rcpp-1.0.1               |    r36h29659fb_0         3.2 MB  defaults
#     r-repr-0.19.2              |    r36h6115d3f_0         143 KB  defaults
#     r-uuid-0.1_2               |    r36h96ca727_4          21 KB  defaults
#     readline-8.1               |       h46c0cb4_0         295 KB  conda-forge
#     sed-4.8                    |       he412f7d_0         264 KB  conda-forge
#     sqlite-3.37.0              |       h9cd32fc_0         1.5 MB  conda-forge
#     sysroot_linux-64-2.12      |      he073ed8_15        31.4 MB  conda-forge
#     tk-8.6.11                  |       h27826a3_1         3.3 MB  conda-forge
#     tktable-2.10               |       hb7b940f_3          89 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.7.2          |       h7f98852_0         941 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zlib-1.2.11                |    h36c2ea0_1013          86 KB  conda-forge
#     zstd-1.5.0                 |       ha95c52a_0         490 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       265.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _r-mutex           conda-forge/noarch::_r-mutex-1.0.1-anacondar_1
#   binutils_impl_lin~ pkgs/main/linux-64::binutils_impl_linux-64-2.35.1-h27ae35d_9
#   binutils_linux-64  pkgs/main/linux-64::binutils_linux-64-2.35.1-h454624a_30
#   bwidget            conda-forge/linux-64::bwidget-1.9.14-ha770c72_1
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.18.1-h7f98852_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-h6cf1ce9_1008
#   curl               pkgs/main/linux-64::curl-7.78.0-h1ccaba5_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1005
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gcc_impl_linux-64  pkgs/main/linux-64::gcc_impl_linux-64-9.3.0-h6df7d76_17
#   gcc_linux-64       pkgs/main/linux-64::gcc_linux-64-9.3.0-h1ee779e_30
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h73d1719_1008
#   gfortran_impl_lin~ pkgs/main/linux-64::gfortran_impl_linux-64-9.3.0-h5abd6ed_17
#   gfortran_linux-64  pkgs/main/linux-64::gfortran_linux-64-9.3.0-hf47db2c_30
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h58526e2_1001
#   gsl                conda-forge/linux-64::gsl-2.6-he838d99_2
#   gxx_impl_linux-64  pkgs/main/linux-64::gxx_impl_linux-64-9.3.0-hbdd7822_17
#   gxx_linux-64       pkgs/main/linux-64::gxx_linux-64-9.3.0-h7e70986_30
#   harfbuzz           conda-forge/linux-64::harfbuzz-2.9.1-h83ec7ef_1
#   icu                conda-forge/linux-64::icu-68.2-h9c3ff4c_0
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   kernel-headers_li~ conda-forge/noarch::kernel-headers_linux-64-2.6.32-he073ed8_15
#   lerc               conda-forge/linux-64::lerc-3.0-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-11_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-11_linux64_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.8-h7f98852_0
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libgcc-devel_linu~ pkgs/main/linux-64::libgcc-devel_linux-64-9.3.0-hb95220a_17
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-9.3.0-ha5ec8a7_17
#   libgfortran5       pkgs/main/linux-64::libgfortran5-9.3.0-ha5ec8a7_17
#   libglib            conda-forge/linux-64::libglib-2.70.2-h174f98d_0
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-11_linux64_openblas
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_1
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.17-pthreads_h8fe5266_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libstdcxx-devel_l~ pkgs/main/linux-64::libstdcxx-devel_linux-64-9.3.0-hf0c5c8d_17
#   libtiff            conda-forge/linux-64::libtiff-4.3.0-h6f004c6_2
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.1-h7f98852_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   libxml2            conda-forge/linux-64::libxml2-2.9.12-h72842e0_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.11-h36c2ea0_1013
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_1
#   make               conda-forge/linux-64::make-4.3-hd18ef5c_1
#   pango              conda-forge/linux-64::pango-1.48.10-hb8ff022_1
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   r-base             conda-forge/linux-64::r-base-3.6.3-hbcea092_8
#   r-base64enc        conda-forge/linux-64::r-base64enc-0.1_3-r36hcfec24a_1004
#   r-crayon           pkgs/r/noarch::r-crayon-1.3.4-r36h6115d3f_0
#   r-digest           pkgs/r/linux-64::r-digest-0.6.18-r36h96ca727_0
#   r-evaluate         conda-forge/noarch::r-evaluate-0.14-r36h6115d3f_2
#   r-htmltools        pkgs/r/linux-64::r-htmltools-0.3.6-r36h29659fb_0
#   r-irdisplay        conda-forge/noarch::r-irdisplay-1.0-r36hd8ed1ab_0
#   r-irkernel         conda-forge/noarch::r-irkernel-1.2-r36hc72bb7e_0
#   r-jsonlite         conda-forge/linux-64::r-jsonlite-1.7.2-r36hcfec24a_0
#   r-pbdzmq           pkgs/r/linux-64::r-pbdzmq-0.3_3-r36h5455479_1
#   r-rcpp             pkgs/r/linux-64::r-rcpp-1.0.1-r36h29659fb_0
#   r-repr             pkgs/r/noarch::r-repr-0.19.2-r36h6115d3f_0
#   r-uuid             pkgs/r/linux-64::r-uuid-0.1_2-r36h96ca727_4
#   sed                conda-forge/linux-64::sed-4.8-he412f7d_0
#   sysroot_linux-64   conda-forge/noarch::sysroot_linux-64-2.12-he073ed8_15
#   tktable            conda-forge/linux-64::tktable-2.10-hb7b940f_3
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.5.0-ha95c52a_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.6.20-hecda079_0 --> 2021.10.8-ha878542_0
#   certifi                          2020.6.20-py37hc8dfbb8_0 --> 2021.10.8-py37h89c1867_1
#   cffi                                1.14.0-py37hd463f26_0 --> 1.15.0-py37h036bc23_0
#   krb5                                    1.17.1-hfafb76e_1 --> 1.19.2-hcc1bbae_3
#   ld_impl_linux-64   conda-forge::ld_impl_linux-64-2.34-h5~ --> pkgs/main::ld_impl_linux-64-2.35.1-h7274673_9
#   libcurl            conda-forge::libcurl-7.71.1-hcdd3856_3 --> pkgs/main::libcurl-7.78.0-h0b77cf5_0
#   libffi                                3.2.1-he1b5a44_1007 --> 3.4.2-h7f98852_5
#   libgcc-ng                                9.2.0-h24d8f2e_2 --> 11.2.0-h1d223b6_11
#   libgomp                                  9.2.0-h24d8f2e_2 --> 11.2.0-h1d223b6_11
#   libstdcxx-ng                             9.2.0-hdf63c60_2 --> 11.2.0-he4da1e4_11
#   openssl                                 1.1.1g-h516909a_0 --> 1.1.1l-h7f98852_0
#   python                           3.7.8-h6f2ec95_0_cpython --> 3.7.12-hb7a2778_100_cpython
#   readline                                   8.0-he28a2e2_2 --> 8.1-h46c0cb4_0
#   sqlite                                  3.32.3-hcee41ef_1 --> 3.37.0-h9cd32fc_0
#   tk                                      8.6.10-hed695b0_0 --> 8.6.11-h27826a3_1
#   zlib                                 1.2.11-h516909a_1006 --> 1.2.11-h36c2ea0_1013
#
#
#
# Downloading and Extracting Packages
# r-irdisplay-1.0      | 35 KB     | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# kernel-headers_linux | 707 KB    | ##################################### | 100%
# zstd-1.5.0           | 490 KB    | ##################################### | 100%
# xorg-libsm-1.2.3     | 26 KB     | ##################################### | 100%
# libffi-3.4.2         | 57 KB     | ##################################### | 100%
# cairo-1.16.0         | 1.5 MB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# tktable-2.10         | 89 KB     | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# cffi-1.15.0          | 225 KB    | ##################################### | 100%
# r-base64enc-0.1_3    | 44 KB     | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# libgcc-devel_linux-6 | 2.8 MB    | ##################################### | 100%
# xorg-libice-1.0.10   | 58 KB     | ##################################### | 100%
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
# gsl-2.6              | 3.2 MB    | ##################################### | 100%
# libstdcxx-devel_linu | 10.6 MB   | ##################################### | 100%
# fribidi-1.0.10       | 112 KB    | ##################################### | 100%
# lz4-c-1.9.3          | 179 KB    | ##################################### | 100%
# libdeflate-1.8       | 67 KB     | ##################################### | 100%
# readline-8.1         | 295 KB    | ##################################### | 100%
# graphite2-1.3.13     | 102 KB    | ##################################### | 100%
# bwidget-1.9.14       | 120 KB    | ##################################### | 100%
# r-digest-0.6.18      | 147 KB    | ##################################### | 100%
# tk-8.6.11            | 3.3 MB    | ##################################### | 100%
# font-ttf-inconsolata | 94 KB     | ##################################### | 100%
# font-ttf-ubuntu-0.83 | 1.9 MB    | ##################################### | 100%
# r-repr-0.19.2        | 143 KB    | ##################################### | 100%
# krb5-1.19.2          | 1.4 MB    | ##################################### | 100%
# xorg-libx11-1.7.2    | 941 KB    | ##################################### | 100%
# libnsl-2.0.0         | 31 KB     | ##################################### | 100%
# harfbuzz-2.9.1       | 2.0 MB    | ##################################### | 100%
# libgcc-ng-11.2.0     | 887 KB    | ##################################### | 100%
# lerc-3.0             | 216 KB    | ##################################### | 100%
# libev-4.33           | 104 KB    | ##################################### | 100%
# xorg-renderproto-0.1 | 9 KB      | ##################################### | 100%
# curl-7.78.0          | 94 KB     | ##################################### | 100%
# binutils_linux-64-2. | 24 KB     | ##################################### | 100%
# libwebp-base-1.2.1   | 845 KB    | ##################################### | 100%
# r-jsonlite-1.7.2     | 462 KB    | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# gfortran_impl_linux- | 8.8 MB    | ##################################### | 100%
# gxx_impl_linux-64-9. | 9.0 MB    | ##################################### | 100%
# icu-68.2             | 13.1 MB   | ##################################### | 100%
# fontconfig-2.13.1    | 357 KB    | ##################################### | 100%
# r-pbdzmq-0.3_3       | 380 KB    | ##################################### | 100%
# c-ares-1.18.1        | 113 KB    | ##################################### | 100%
# font-ttf-source-code | 684 KB    | ##################################### | 100%
# pixman-0.40.0        | 627 KB    | ##################################### | 100%
# gcc_linux-64-9.3.0   | 25 KB     | ##################################### | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ##################################### | 100%
# gxx_linux-64-9.3.0   | 24 KB     | ##################################### | 100%
# zlib-1.2.11          | 86 KB     | ##################################### | 100%
# ld_impl_linux-64-2.3 | 586 KB    | ##################################### | 100%
# pcre-8.45            | 253 KB    | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# libgomp-11.2.0       | 427 KB    | ##################################### | 100%
# libcurl-7.78.0       | 338 KB    | ##################################### | 100%
# libstdcxx-ng-11.2.0  | 4.2 MB    | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# libglib-2.70.2       | 3.1 MB    | ##################################### | 100%
# _r-mutex-1.0.1       | 3 KB      | ##################################### | 100%
# openssl-1.1.1l       | 2.1 MB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# gcc_impl_linux-64-9. | 44.6 MB   | ##################################### | 100%
# fonts-conda-ecosyste | 4 KB      | ##################################### | 100%
# libgfortran5-9.3.0   | 1.5 MB    | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# binutils_impl_linux- | 3.6 MB    | ##################################### | 100%
# libtiff-4.3.0        | 614 KB    | ##################################### | 100%
# r-evaluate-0.14      | 81 KB     | ##################################### | 100%
# certifi-2021.10.8    | 145 KB    | ##################################### | 100%
# sysroot_linux-64-2.1 | 31.4 MB   | ##################################### | 100%
# libxml2-2.9.12       | 772 KB    | ##################################### | 100%
# r-rcpp-1.0.1         | 3.2 MB    | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# libopenblas-0.3.17   | 9.2 MB    | ##################################### | 100%
# r-crayon-1.3.4       | 757 KB    | ##################################### | 100%
# r-htmltools-0.3.6    | 172 KB    | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
# libxcb-1.13          | 391 KB    | ##################################### | 100%
# ca-certificates-2021 | 139 KB    | ##################################### | 100%
# libnghttp2-1.43.0    | 790 KB    | ##################################### | 100%
# python-3.7.12        | 57.3 MB   | ##################################### | 100%
# r-base-3.6.3         | 23.4 MB   | ##################################### | 100%
# pango-1.48.10        | 400 KB    | ##################################### | 100%
# sqlite-3.37.0        | 1.5 MB    | ##################################### | 100%
# r-irkernel-1.2       | 157 KB    | ##################################### | 100%
# libzlib-1.2.11       | 59 KB     | ##################################### | 100%
# r-uuid-0.1_2         | 21 KB     | ##################################### | 100%
# xorg-libxrender-0.9. | 32 KB     | ##################################### | 100%
# make-4.3             | 507 KB    | ##################################### | 100%
# sed-4.8              | 264 KB    | ##################################### | 100%
# gfortran_linux-64-9. | 24 KB     | ##################################### | 100%
# jbig-2.1             | 43 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
