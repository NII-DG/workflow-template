# %% [markdown]
# # 研究データを追加する
#
# これはDMP情報に基づき、研究リポジトリを更新するためのノートブックです。

# %% [markdown]
# ## 1. 追加したい研究データ情報を変数に入力する

# %%
data_name = ''
...

# %% [markdown]
# ## 2. 研究データを研究リポジトリに追加する

# %% [markdown]
# ## 3. フローに埋め込まれているdmp.jsonに追加する研究データを書き込む
